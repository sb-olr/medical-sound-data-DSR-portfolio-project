# %% [markdown]
# <a href="https://colab.research.google.com/github/sb-olr/medical-sound-data-DSR-portfolio-project/blob/main/data_download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# ls: cannot open directory '.': Transport endpoint is not connected

# %%
#!wget https://www.kaggle.com/praveengovi/coronahack-respiratory-sound-dataset/download
# Out:
# --2021-09-24 13:22:04--  https://www.kaggle.com/praveengovi/coronahack-respiratory-sound-dataset/download
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /account/login?titleType=dataset-downloads&showDatasetDownloadSkip=False&messageId=datasetsWelcome&returnUrl=%2Fpraveengovi%2Fcoronahack-respiratory-sound-dataset%3Fresource%3Ddownload [following]
# --2021-09-24 13:22:04--  https://www.kaggle.com/account/login?titleType=dataset-downloads&showDatasetDownloadSkip=False&messageId=datasetsWelcome&returnUrl=%2Fpraveengovi%2Fcoronahack-respiratory-sound-dataset%3Fresource%3Ddownload
# Reusing existing connection to www.kaggle.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘download’
#
# download                [ <=>                ]   6.48K  --.-KB/s    in 0.001s
#
# ...

# %%
#! pip install kaggle

# %%
! mkdir ~/.kaggle

# %%
! cd ~/.kaggle

# %%
! echo '{"username":"paulgrzesik","key":"0f88c4f13b9b3a15d91cff9830ccc3b3"}' > kaggle.json

# %%
! mv kaggle.json ~/.kaggle

# %%
! chmod 600 kaggle.json
# Out:
# chmod: cannot access 'kaggle.json': No such file or directory

# %%
! pwd
# Out:
# /content/gdrive/My Drive

# %%
! kaggle datasets download -d praveengovi/coronahack-respiratory-sound-dataset
# Out:
# coronahack-respiratory-sound-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
! unzip coronahack-respiratory-sound-dataset.zip
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#   inflating: CoronaHack-Respiratory-Sound-Dataset/data/train/20200419/PAngvEIaGxXq92VkTOyQPquFkVI2/breathing-deep.wav
#   inflating: CoronaHack-Respiratory-Sound-Dataset/data/train/20200419/PAngvEIaGxXq92VkTOyQPquFkVI2/breathing-shallow.wav
#   inflating: CoronaHack-Respiratory-Sound-Dataset/data/train/20200419/PAngvEIaGxXq92VkTOyQPquFkVI2/cough-heavy.wav
#   inflating: CoronaHack-Respiratory-Sound-Dataset/data/train/20200419/PAngvEIaGxXq92VkTOyQPquFkVI2/cough-shallow.wav
#   inflating: CoronaHack-Respiratory-Sound-Dataset/data/train/20200419/PAngvEIaGxXq92VkTOyQPquFkVI2/counting-fast.wav
#   inflating: CoronaHack-Respiratory-Sound-Dataset/data/train/20200419/PAngvEIaGxXq92VkTOyQPquFkVI2/counting-normal.wav
#   inflating: CoronaHack-Respiratory-Sound-Dataset/data/train/20200419/PAngvEIaGxXq92VkTOyQPquFkVI2/metadata.json
# ...
